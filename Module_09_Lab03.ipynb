# %% [markdown]
# <a href="https://colab.research.google.com/github/akanksharaut21/Firstlab_ML_AKANKSHARAUT/blob/main/Module_09_Lab03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module 9: Neural Networks
#
# Lab 2: Using MLP for multiclass classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the iris dataset
iris = load_iris()
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']

# Scale data to have mean 0 and variance 1
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data set into training and testing
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=2)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax1.plot(X_plot[:, 0], X_plot[:, 1],
             linestyle='none',
             marker='o',
             label=target_name)
ax1.set_xlabel(feature_names[0])
ax1.set_ylabel(feature_names[1])
ax1.axis('equal')
ax1.legend();

for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax2.plot(X_plot[:, 2], X_plot[:, 3],
             linestyle='none',
             marker='o',
             label=target_name)
ax2.set_xlabel(feature_names[2])
ax2.set_ylabel(feature_names[3])
ax2.axis('equal')
ax2.legend();

# %% [markdown]
# MLP for multiclass classification

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable
import tqdm

# %%
# Defining the model architecture
class Model(nn.Module):
    def __init__(self, input_dim):
        super(Model, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(50, 3)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %%
# Instantiating the model, using Adam optimiser, and Cross Entropy Loss, which is quite commonlu used for classification tasks.
model     = Model(X_train.shape[1])
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn   = nn.CrossEntropyLoss()

# %% [markdown]
# Train the model

# %%
# Train for 100 epochs
EPOCHS  = 100
X_train = torch.from_numpy(X_train).float()
X_test= torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test)
y_train = torch.from_numpy(y_train)


loss_list     = np.zeros((EPOCHS,))
accuracy_list = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list[epoch] = loss.item()

    # Zero gradients
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    with torch.no_grad():
        y_pred = model(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list[epoch] = correct.mean()
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 92.14it/s]

# %% [markdown]
# Plot training progress

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)

ax1.plot(accuracy_list)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs");

# %% [markdown]
# Experiment with the neural network architecture
#
# 1)Try changing the number of hidden layers.
#
# 2)Try changing the number of neurons in the hidden layer.
#
# 3)Try using a different activation function.
# Can you observe any changes?

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, activations
from tensorflow.keras.datasets import mnist

# Load and preprocess the data
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# Base Model
def create_base_model():
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(128, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Experiment 1: Change the number of hidden layers
def create_model_exp1(num_hidden_layers):
    model = models.Sequential()
    model.add(layers.Flatten(input_shape=(28, 28)))
    for _ in range(num_hidden_layers):
        model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))
    return model

# Experiment 2: Change the number of neurons in the hidden layer
def create_model_exp2(num_neurons):
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(num_neurons, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Experiment 3: Use a different activation function
def create_model_exp3(activation_func):
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(128, activation=activation_func),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Train and evaluate a given model
def train_and_evaluate(model):
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    model.fit(train_images, train_labels, epochs=5, validation_data=(test_images, test_labels))

# Base Model
print("Base Model:")
base_model = create_base_model()
train_and_evaluate(base_model)

# Experiment 1: Change the number of hidden layers
print("\nExperiment 1: Change the number of hidden layers")
for num_hidden_layers in [1, 2, 3]:
    print(f"\nNumber of hidden layers: {num_hidden_layers}")
    model_exp1 = create_model_exp1(num_hidden_layers)
    train_and_evaluate(model_exp1)

# Experiment 2: Change the number of neurons in the hidden layer
print("\nExperiment 2: Change the number of neurons in the hidden layer")
for num_neurons in [64, 128, 256]:
    print(f"\nNumber of neurons in the hidden layer: {num_neurons}")
    model_exp2 = create_model_exp2(num_neurons)
    train_and_evaluate(model_exp2)

# Experiment 3: Use a different activation function
print("\nExperiment 3: Use a different activation function")
activation_functions = ['relu', 'tanh', 'sigmoid']
for activation_func in activation_functions:
    print(f"\nActivation function: {activation_func}")
    model_exp3 = create_model_exp3(activation_func)
    train_and_evaluate(model_exp3)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Base Model:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2575 - accuracy: 0.9252 - val_loss: 0.1368 - val_accuracy: 0.9594
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1136 - accuracy: 0.9658 - val_loss: 0.0986 - val_accuracy: 0.9699
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0780 - accuracy: 0.9768 - val_loss: 0.0872 - val_accuracy: 0.9735
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0588 - accuracy: 0.9822 - val_loss: 0.0748 - val_accuracy: 0.9768
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0447 - accuracy: 0.9861 - val_loss: 0.0758 - val_accuracy: 0.9772
#
# Experiment 1: Change the number of hidden layers
#
# Number of hidden layers: 1
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2612 - accuracy: 0.9252 - val_loss: 0.1440 - val_accuracy: 0.9571
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1150 - accuracy: 0.9653 - val_loss: 0.1017 - val_accuracy: 0.9695
# Epoch 3/5
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0794 - accuracy: 0.9755 - val_loss: 0.0877 - val_accuracy: 0.9742
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0580 - accuracy: 0.9820 - val_loss: 0.0785 - val_accuracy: 0.9760
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0455 - accuracy: 0.9855 - val_loss: 0.0804 - val_accuracy: 0.9761
#
# Number of hidden layers: 2
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2286 - accuracy: 0.9321 - val_loss: 0.1157 - val_accuracy: 0.9638
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0979 - accuracy: 0.9697 - val_loss: 0.0927 - val_accuracy: 0.9719
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0693 - accuracy: 0.9783 - val_loss: 0.0834 - val_accuracy: 0.9736
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0532 - accuracy: 0.9826 - val_loss: 0.0720 - val_accuracy: 0.9782
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0419 - accuracy: 0.9865 - val_loss: 0.0774 - val_accuracy: 0.9776
#
# Number of hidden layers: 3
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2262 - accuracy: 0.9335 - val_loss: 0.1247 - val_accuracy: 0.9594
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0996 - accuracy: 0.9692 - val_loss: 0.1036 - val_accuracy: 0.9682
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0701 - accuracy: 0.9776 - val_loss: 0.0761 - val_accuracy: 0.9767
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0547 - accuracy: 0.9829 - val_loss: 0.0856 - val_accuracy: 0.9773
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0462 - accuracy: 0.9856 - val_loss: 0.0741 - val_accuracy: 0.9798
#
# Experiment 2: Change the number of neurons in the hidden layer
#
# Number of neurons in the hidden layer: 64
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3050 - accuracy: 0.9140 - val_loss: 0.1692 - val_accuracy: 0.9506
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1482 - accuracy: 0.9572 - val_loss: 0.1297 - val_accuracy: 0.9622
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1088 - accuracy: 0.9679 - val_loss: 0.1081 - val_accuracy: 0.9678
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0853 - accuracy: 0.9729 - val_loss: 0.0940 - val_accuracy: 0.9708
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0695 - accuracy: 0.9781 - val_loss: 0.0955 - val_accuracy: 0.9715
#
# Number of neurons in the hidden layer: 128
# Epoch 1/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2624 - accuracy: 0.9254 - val_loss: 0.1365 - val_accuracy: 0.9598
# Epoch 2/5
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.1157 - accuracy: 0.9658 - val_loss: 0.1051 - val_accuracy: 0.9662
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0788 - accuracy: 0.9761 - val_loss: 0.0979 - val_accuracy: 0.9692
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0598 - accuracy: 0.9814 - val_loss: 0.0833 - val_accuracy: 0.9736
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0459 - accuracy: 0.9862 - val_loss: 0.0898 - val_accuracy: 0.9710
#
# Number of neurons in the hidden layer: 256
# Epoch 1/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2269 - accuracy: 0.9342 - val_loss: 0.1229 - val_accuracy: 0.9638
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0936 - accuracy: 0.9716 - val_loss: 0.0863 - val_accuracy: 0.9741
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0611 - accuracy: 0.9810 - val_loss: 0.0814 - val_accuracy: 0.9765
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0444 - accuracy: 0.9859 - val_loss: 0.0736 - val_accuracy: 0.9785
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0331 - accuracy: 0.9895 - val_loss: 0.0696 - val_accuracy: 0.9785
#
# Experiment 3: Use a different activation function
#
# Activation function: relu
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2672 - accuracy: 0.9236 - val_loss: 0.1388 - val_accuracy: 0.9587
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1170 - accuracy: 0.9661 - val_loss: 0.1050 - val_accuracy: 0.9673
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0798 - accuracy: 0.9760 - val_loss: 0.0828 - val_accuracy: 0.9750
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0587 - accuracy: 0.9818 - val_loss: 0.0878 - val_accuracy: 0.9734
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0455 - accuracy: 0.9859 - val_loss: 0.0784 - val_accuracy: 0.9744
#
# Activation function: tanh
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2847 - accuracy: 0.9183 - val_loss: 0.1743 - val_accuracy: 0.9475
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1358 - accuracy: 0.9613 - val_loss: 0.1133 - val_accuracy: 0.9662
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0907 - accuracy: 0.9745 - val_loss: 0.0943 - val_accuracy: 0.9705
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0659 - accuracy: 0.9808 - val_loss: 0.0862 - val_accuracy: 0.9736
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0504 - accuracy: 0.9853 - val_loss: 0.0780 - val_accuracy: 0.9757
#
# Activation function: sigmoid
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3969 - accuracy: 0.8967 - val_loss: 0.2279 - val_accuracy: 0.9340
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1960 - accuracy: 0.9435 - val_loss: 0.1673 - val_accuracy: 0.9494
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1431 - accuracy: 0.9584 - val_loss: 0.1307 - val_accuracy: 0.9606
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1104 - accuracy: 0.9684 - val_loss: 0.1075 - val_accuracy: 0.9676
# Epoch 5/5
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0887 - accuracy: 0.9748 - val_loss: 0.0948 - val_accuracy: 0.9701
